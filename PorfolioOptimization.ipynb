# %% [markdown]
# <a href="https://colab.research.google.com/github/tanduong/N/blob/master/PorfolioOptimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance numpy pandas scipy matplotlib plotly joblib vnstock

# %%
from vnstock import Vnstock
from vnstock import Listing, Quote, Company, Finance, Trading, Screener
''

# %%
from joblib import Memory
import os

# Set up cache directory
memory = Memory(location='./cache', verbose=0)

@memory.cache
def get_ticker_data(ticker, start, end):
  try:
    stock = Vnstock().stock(symbol=ticker, source='VCI')
    df = stock.quote.history(start=start, end=end, interval='1D')
    data = df[['time', 'close']].copy()
    data.rename(columns={'time': 'Date', 'close': 'Close'}, inplace=True)
    data['Ticker'] = ticker
    return data
  except Exception as e:
    print(f"Error fetching data for {ticker}: {e}")
    return pd.DataFrame()

def get_data(tickers, start, end):
    data = pd.concat([get_ticker_data(ticker, start, end) for ticker in tickers])
    return data.pivot(index='Date', columns='Ticker', values='Close')

def format_weights(weights, tickers, threshold=0.001):
    nonzero = [(ticker, round(float(w), 4)) for ticker, w in zip(tickers, weights) if abs(w) > threshold]
    return ', '.join(f'{ticker}: {w:.2f}' for ticker, w in nonzero)

# %%
import io
import pandas as pd

custom_portfolio = pd.read_csv(io.StringIO('''
ACB,7000,$21.80,"$152,600.00",9.89%
FUEVFVND,300,$25.88,"$7,764.00",0.50%
GMD,1000,$42.20,"$42,200.00",2.74%
HPG,17500,$21.30,"$372,750.00",24.16%
MSN,0,$50.30,$0.00,0.00%
NVL,10000,$8.10,"$81,000.00",5.25%
PNJ,4000,$62.80,"$251,200.00",16.28%
REE,100,$61.00,"$6,100.00",0.40%
VCB,0,$52.50,$0.00,0.00%
VNM,12100,$52.00,"$629,200.00",40.78%
'''), header=None)

custom_portfolio = pd.DataFrame({'Ticker': custom_portfolio[0], 'Weight': custom_portfolio[4].str.replace('%', '').astype(float) / 100
})

custom_portfolio = custom_portfolio.set_index('Ticker')['Weight'].to_dict()

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from scipy.optimize import minimize
import plotly.express as px
import plotly.graph_objects as go

custom_bounds = {
    'VCB': (0, 0.15),
}

MAX_WEIGHT = 0.1

def portfolio_performance(expected_returns, cov_matrix, weights):
    ret = np.dot(weights, expected_returns)
    vol = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))
    return ret, vol

def minimize_volatility(tickers, expected_returns, cov_matrix, target_return):
    num_assets = len(tickers)
    bounds = tuple(custom_bounds.get(ticker, (0, MAX_WEIGHT)) for ticker in tickers)

    constraints = (
        {'type': 'eq', 'fun': lambda w: np.sum(w) - 1},
        {'type': 'eq', 'fun': lambda w: np.dot(w, expected_returns) - target_return}
    )
    initial_guess = num_assets * [1. / num_assets]

    result = minimize(
        lambda w: portfolio_performance(expected_returns, cov_matrix, w)[1],
        initial_guess,
        method='SLSQP',
        bounds=bounds,
        constraints=constraints
    )
    return result

def optimize_portfolio(tickers, expected_returns, cov_matrix, target_returns):
  results = []
  for target in target_returns:
      # Step 4: Optimize performance
      res = minimize_volatility(tickers, expected_returns, cov_matrix, target)
      if res.success:
          ret, vol = portfolio_performance(expected_returns, cov_matrix, res.x)
          results.append({
              'Return': ret,
              'Volatility': vol,
              'Weights': res.x,
              **{f'{ticker}_weight': round(w, 4) for ticker, w in zip(tickers, res.x)}
          })
  return pd.DataFrame(results)

def plot_portfolios(tickers, expected_returns, cov_matrix, results, custom_portfolio={}):
  single_asset_results = []

  for i, ticker in enumerate(tickers):
      w = np.zeros(len(tickers))
      w[i] = 1.0  # 100% in one asset
      ret, vol = portfolio_performance(expected_returns, cov_matrix, w)
      single_asset_results.append({
          'Return': ret,
          'Volatility': vol,
          'Label': f'{ticker}'
      })

  single_df = pd.DataFrame(single_asset_results)

  # Plot efficient frontier
  fig = go.Figure()

  fig.add_trace(go.Scatter(
      x=results['Volatility'], y=results['Return'],
      mode='markers',
      marker=dict(size=8, color='blue', line=dict(width=1, color='DarkSlateGrey')),
      name='Efficient Frontier',
      text=[f"Weights: {format_weights(row['Weights'], tickers)}" for _, row in results.iterrows()],
      hoverinfo='text+y+x'
  ))

  # Add single-stock points
  fig.add_trace(go.Scatter(
      x=single_df['Volatility'], y=single_df['Return'],
      mode='markers+text',
      marker=dict(size=10, color='red', symbol='diamond'),
      text=single_df['Label'],
      name='Single Stocks',
      hoverinfo='text+y+x',
      textposition='top center'
  ))

  fig.update_layout(
      title='Efficient Frontier with Single Stock Portfolios',
      xaxis_title='Risk (Std Dev)',
      yaxis_title='Expected Return',
      template='plotly_white',
      height=1000,
      width=1200
  )


  if custom_portfolio:
    weights = np.array([custom_portfolio.get(t, 0.0) for t in tickers])

    # Compute performance
    custom_return = np.dot(weights, expected_returns)
    custom_volatility = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))

    fig.add_trace(go.Scatter(
        x=[custom_volatility],
        y=[custom_return],
        mode='markers+text',
        marker=dict(size=12, color='green', symbol='star'),
        name='Custom Portfolio',
        textposition='bottom center',
        hoverinfo='text+y+x',
        text=["Custom Portfolio"],
        hovertext=[', '.join(f'{ticker}: {weight*100:.0f}%' for ticker, weight in custom_portfolio.items())],
    ))

  fig.show()

def plot_cov(cov_matrix):
  import plotly.express as px

  fig = px.imshow(
      cov_matrix,
      text_auto=".2f",
      color_continuous_scale='Blues',
      title='Covariance Matrix',
      labels=dict(color='Covariance')
  )
  fig.update_layout(width=1400, height=1400)
  fig.show()

# %%
def top_correlated_tickers(cov_matrix, ticker, top_n=10):
    # Convert covariance matrix to correlation matrix
    std_devs = np.sqrt(np.diag(cov_matrix))
    corr_matrix = cov_matrix / np.outer(std_devs, std_devs)
    corr_df = pd.DataFrame(corr_matrix, index=cov_matrix.index, columns=cov_matrix.columns)

    # Drop self-correlation and sort
    correlations = corr_df[ticker].drop(ticker).sort_values(ascending=False)

    return correlations.head(top_n)

# %% [markdown]
# ## VN30

# %%
stock = Vnstock().stock(symbol='VN30F1M', source='VCI')
vn30tickers = list(stock.listing.symbols_by_group('VN30'))
# Out:
# 2025-04-10 15:12:24 - vnstock.common.data.data_explorer - INFO - Không phải là mã chứng khoán, thông tin công ty và tài chính không khả dụng.
# INFO:vnstock.common.data.data_explorer:Không phải là mã chứng khoán, thông tin công ty và tài chính không khả dụng.

# %%
# Step 1: Download historical price data (using 'Close')
# tickers = ['ACB', 'PNJ', 'VNM', 'HPG', 'MWG', 'REE', 'VIC', 'VCB', 'GAS', 'BID', 'HAG']

start = '2015-12-31'
end = '2025-04-10'
data = get_data(vn30tickers, start, end)
returns = data.pct_change().dropna()

# Step 2: Calculate expected returns and covariance matrix
expected_returns = returns.mean() * 252  # annualized
cov_matrix = returns.cov() * 252         # annualized

# Step 3: Generate efficient frontier
target_returns = np.linspace(-0.05, 0.5, 50)

results = optimize_portfolio(vn30tickers, expected_returns, cov_matrix, target_returns)
# Out:
# 📋 Kết nối tài khoản Google Drive để lưu các thiết lập của dự án.
# Dữ liệu phiên làm việc với Colab của bạn sẽ bị xóa nếu không lưu trữ vào Google Drive.
#
# Mounted at /content/drive
# The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.

# %%
plot_portfolios(vn30tickers, expected_returns, cov_matrix, results, custom_portfolio)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="46e5895b-87a3-4cbc-9d7c-beb2abb43ea4" class="plotly-graph-div" style="height:1000px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46e5895b-87a3-4cbc-9d7c-beb2abb43ea4")) {                    Plotly.newPlot(                        "46e5895b-87a3-4cbc-9d7c-beb2abb43ea4",                        [{"hoverinfo":"text+y+x","marker":{"color":"blue","line":{"color":"DarkSlateGrey","width":1},"size":8},"mode":"markers","name":"Efficient Frontier","text":["Weights: BVH: 0.10, GAS: 0.10, MSN: 0.03, PLX: 0.10, SAB: 0.10, VCB: 0.07, VHM: 0.10, VIC: 0.10, VJC: 0.10, VNM: 0.10, VRE: 0.10","Weights: BVH: 0.10, GAS: 0.10, PLX: 0.10, SAB: 0.10, SSB: 0.01, VCB: 0.13, VHM: 0.10, VIC: 0.10, VJC: 0.10, VNM: 0.10, VRE: 0.06","Weights: BVH: 0.10, GAS: 0.10, PLX: 0.10, SAB: 0.10, SSB: 0.05, VCB: 0.13, VHM: 0.10, VIC: 0.10, VJC: 0.10, VNM: 0.10, VRE: 0.02","Weights: BVH: 0.08, GAS: 0.10, PLX: 0.10, SAB: 0.10, SSB: 0.08, VCB: 0.15, VHM: 0.08, VIC: 0.10, VJC: 0.10, VNM: 0.10, VRE: 0.01","Weights: ACB: 0.01, BCM: 0.03, BVH: 0.06, GAS: 0.09, PLX: 0.09, SAB: 0.10, SSB: 0.10, VCB: 0.15, VHM: 0.06, VIB: 0.01, VIC: 0.10, VJC: 0.10, VNM: 0.10","Weights: ACB: 0.04, BCM: 0.04, BVH: 0.04, FPT: 0.01, GAS: 0.09, PLX: 0.07, SAB: 0.10, SSB: 0.10, VCB: 0.15, VHM: 0.04, VIB: 0.02, VIC: 0.10, VJC: 0.10, VNM: 0.10","Weights: ACB: 0.05, BCM: 0.04, BVH: 0.04, FPT: 0.04, GAS: 0.09, PLX: 0.06, SAB: 0.10, SSB: 0.10, VCB: 0.15, VHM: 0.03, VIB: 0.01, VIC: 0.10, VJC: 0.10, VNM: 0.10","Weights: ACB: 0.05, BCM: 0.05, BVH: 0.03, FPT: 0.07, GAS: 0.08, PLX: 0.04, SAB: 0.10, SSB: 0.10, VCB: 0.15, VHM: 0.02, VIB: 0.01, VIC: 0.10, VJC: 0.10, VNM: 0.10","Weights: ACB: 0.06, BCM: 0.05, BVH: 0.02, FPT: 0.10, GAS: 0.08, HDB: 0.00, PLX: 0.03, SAB: 0.10, SSB: 0.10, VCB: 0.15, VHM: 0.00, VIB: 0.01, VIC: 0.10, VJC: 0.10, VNM: 0.10","Weights: ACB: 0.07, BCM: 0.06, BVH: 0.00, FPT: 0.10, GAS: 0.07, HDB: 0.02, LPB: 0.01, PLX: 0.01, SAB: 0.10, SSB: 0.10, VCB: 0.15, VIB: 0.00, VIC: 0.10, VJC: 0.10, VNM: 0.10","Weights: ACB: 0.07, BCM: 0.06, FPT: 0.10, GAS: 0.07, HDB: 0.03, LPB: 0.03, SAB: 0.10, SSB: 0.10, VCB: 0.15, VIC: 0.10, VJC: 0.10, VNM: 0.10","Weights: ACB: 0.06, BCM: 0.06, FPT: 0.10, GAS: 0.05, HDB: 0.03, LPB: 0.06, SAB: 0.10, SSB: 0.10, VCB: 0.15, VIC: 0.09, VJC: 0.10, VNM: 0.10","Weights: ACB: 0.05, BCM: 0.06, FPT: 0.10, GAS: 0.04, HDB: 0.03, LPB: 0.08, SAB: 0.10, SSB: 0.10, VCB: 0.15, VIC: 0.08, VJC: 0.10, VNM: 0.10","Weights: ACB: 0.05, BCM: 0.07, FPT: 0.10, GAS: 0.03, HDB: 0.04, LPB: 0.10, SAB: 0.10, SSB: 0.10, VCB: 0.15, VIC: 0.06, VJC: 0.10, VNM: 0.10","Weights: ACB: 0.07, BCM: 0.08, FPT: 0.10, GAS: 0.03, HDB: 0.06, LPB: 0.10, SAB: 0.09, SSB: 0.10, VCB: 0.15, VIC: 0.05, VJC: 0.10, VNM: 0.08","Weights: ACB: 0.09, BCM: 0.08, FPT: 0.10, GAS: 0.02, HDB: 0.08, LPB: 0.10, SAB: 0.08, SSB: 0.10, VCB: 0.15, VIC: 0.04, VJC: 0.10, VNM: 0.06","Weights: ACB: 0.10, BCM: 0.10, FPT: 0.10, GAS: 0.03, HDB: 0.10, LPB: 0.10, SAB: 0.06, SSB: 0.10, VCB: 0.15, VIC: 0.02, VJC: 0.10, VNM: 0.04","Weights: ACB: 0.10, BCM: 0.10, FPT: 0.10, GAS: 0.03, HDB: 0.10, LPB: 0.10, MBB: 0.04, SAB: 0.05, SSB: 0.10, VCB: 0.15, VIC: 0.01, VJC: 0.10, VNM: 0.02","Weights: ACB: 0.10, BCM: 0.10, FPT: 0.10, GAS: 0.03, HDB: 0.10, LPB: 0.10, MBB: 0.07, SAB: 0.03, SSB: 0.10, STB: 0.01, VCB: 0.15, VIC: 0.00, VJC: 0.10","Weights: ACB: 0.10, BCM: 0.10, BID: 0.00, FPT: 0.10, GAS: 0.03, HDB: 0.10, LPB: 0.10, MBB: 0.10, SAB: 0.01, SSB: 0.10, STB: 0.02, VCB: 0.15, VJC: 0.09","Weights: ACB: 0.10, BCM: 0.10, BID: 0.02, FPT: 0.10, GAS: 0.03, HDB: 0.10, LPB: 0.10, MBB: 0.10, SSB: 0.10, STB: 0.05, VCB: 0.15, VJC: 0.06","Weights: ACB: 0.10, BCM: 0.10, BID: 0.02, FPT: 0.10, GAS: 0.02, HDB: 0.10, LPB: 0.10, MBB: 0.10, SSB: 0.10, STB: 0.08, VCB: 0.15, VJC: 0.03","Weights: ACB: 0.10, B ...

# %%
plot_cov(cov_matrix)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="24c4efb1-5c91-4de8-9899-4e18b0439b73" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24c4efb1-5c91-4de8-9899-4e18b0439b73")) {                    Plotly.newPlot(                        "24c4efb1-5c91-4de8-9899-4e18b0439b73",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z:.2f}","x":["ACB","BCM","BID","BVH","CTG","FPT","GAS","GVR","HDB","HPG","LPB","MBB","MSN","MWG","PLX","SAB","SHB","SSB","SSI","STB","TCB","TPB","VCB","VHM","VIB","VIC","VJC","VNM","VPB","VRE"],"y":["ACB","BCM","BID","BVH","CTG","FPT","GAS","GVR","HDB","HPG","LPB","MBB","MSN","MWG","PLX","SAB","SHB","SSB","SSI","STB","TCB","TPB","VCB","VHM","VIB","VIC","VJC","VNM","VPB","VRE"],"z":[[0.07321637436977843,0.0271288417336361,0.05277382879532291,0.03581677441062193,0.058773586948892106,0.03671183071224467,0.02542953195911134,0.05881661657687004,0.048906490271226656,0.04805345995987855,0.06392330892699404,0.061235381449784944,0.03540361366844145,0.04506923418099392,0.03395973709946872,0.013453580321929526,0.05864720222998813,0.024184447044648335,0.06488956093665502,0.06595831370206237,0.06115041998805745,0.052773265151499736,0.030984753505323766,0.03187357139653538,0.05276868314544272,0.021028699345863603,0.014511997909487324,0.020742631981053895,0.049491593116889464,0.03819712416847281],[0.0271288417336361,0.12087845049288684,0.03346878873769227,0.03718855528138117,0.03619551592788896,0.02957734830051443,0.039091038136315016,0.06418349570690007,0.029684701941852305,0.03663347116025719,0.030670696767976634,0.03486341015592809,0.0420881216145134,0.044334821329932037,0.031459906760439374,0.017930319989872986,0.033656962090700786,0.01474297945703085,0.04982831868013161,0.0431755986535002,0.03446618599760594,0.03539344510184218,0.0200560954176926,0.03383955811009317,0.03226460875899751,0.024183061581198567,0.016468067832972538,0.01693375889416764,0.03451995144149786,0.0417643309980623],[0.05277382879532291,0.03346878873769227,0.1019596067325547,0.04329093370799253,0.07348230148885161,0.0374228004470118,0.03313371974648801,0.06447598110568173,0.053408363501002726,0.05315239542757499,0.06773993577130819,0.06612068989391288,0.04023919685329713,0.04944501029145987,0.04065363627284875,0.020245085479627275,0.060484504377263854,0.025725681080996612,0.07327189051089432,0.07621277038639585,0.06197522732382146,0.056109101893364585,0.03564417714667344,0.03418145569353703,0.054688265676342836,0.02403212914215179,0.015727286439834544,0.025897048847960815,0.05210491860462224,0.05214560597901354],[0.03581677441062193,0.03718855528138117,0.04329093370799253,0.09300767739839076,0.04546851638672546,0.034305861640873195,0.036526511529658905,0.0718017754373252,0.03429724236411438,0.04485446398126387,0.04446564200503621,0.043840712255034484,0.04259880631008519,0.04839064528404828,0.04472414215240297,0.022464008837664005,0.046980201873916244,0.019505298525529582,0.059707671951418476,0.04715173527161058,0.04188612592325616,0.03793890996137499,0.021138058125230976,0.031018878817488653,0.038824899750022346,0.01999881094822569,0.017566254991301662,0.026103464509920807,0.04024385201904775,0.039776472850682795],[0.058773586948892106,0.03619551592788896,0.07348230148885161,0.04546851638672546,0.1075289756174631,0.04270522410193295,0.03409638957032524,0.06912664204522816,0.0609833662634557,0.06166967365244388,0.07744664404001941,0.07679663664237803,0.047632474129921006,0.05466186586817034,0.04028680125841423,0.01971353303083355,0.06662810621603198,0.029204684541228692,0.0865497239750368,0.08374903190171445,0.07084417908001575,0.06711608198132461,0.03825455700802986,0.03932380862215905,0.06271279073295254,0.0283850841191234,0.015355045492683602,0.02345878327 ...

# %%
top_correlated_tickers(cov_matrix, 'HPG', top_n=10)
# Out:
# Ticker
# SSI    0.621103
# MBB    0.581193
# TCB    0.542661
# CTG    0.541581
# GVR    0.513887
# ACB    0.511417
# STB    0.510508
# VPB    0.506596
# VIB    0.500855
# TPB    0.490019
# Name: HPG, dtype: float64

# %%
top_correlated_tickers(cov_matrix, 'VNM', top_n=10)
# Out:
# Ticker
# BVH    0.387280
# FPT    0.383886
# VCB    0.372956
# BID    0.366963
# MSN    0.358456
# ACB    0.346853
# VRE    0.345042
# MBB    0.342484
# SSI    0.337693
# PLX    0.335870
# Name: VNM, dtype: float64

# %%
top_correlated_tickers(cov_matrix, 'ACB', top_n=10)
# Out:
# Ticker
# MBB    0.738374
# TCB    0.691040
# CTG    0.662392
# STB    0.629827
# BID    0.610802
# VIB    0.597760
# VPB    0.592146
# LPB    0.591753
# HDB    0.587338
# TPB    0.583482
# Name: ACB, dtype: float64

# %%
# top_correlated_tickers(cov_matrix, 'PNJ', top_n=10)

# %% [markdown]
# ## VN100

# %%
tickers = list(stock.listing.symbols_by_group('VN100'))
# tickers

# %%
expected_returns = None
cov_matrix = None
results = None
returns = None
data = None


# Step 1: Download historical price data (using 'Close')
# Should be longer than a year, should be few years
# start = '2015-12-31'
# end = '2025-04-10'

data = get_data(tickers, start, end)
returns = data.pct_change().dropna()

# Step 2: Calculate expected returns and covariance matrix
expected_returns = returns.mean() * 252  # annualized
cov_matrix = returns.cov() * 252         # annualized
# Out:
# Error fetching data for IMP: Failed to fetch data: 502 - Bad Gateway
# <ipython-input-17-68c3469411da>:14: FutureWarning:
#
# The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.

# %%
# Step 3: Generate efficient frontier
target_returns = np.linspace(-0.05, 0.5, 30)
tickers = list(data.columns)
results = optimize_portfolio(tickers, expected_returns, cov_matrix, target_returns)

# %%
plot_portfolios(tickers, expected_returns, cov_matrix, results, custom_portfolio)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="42fe3d1d-e374-4dc4-a954-fd2143623faf" class="plotly-graph-div" style="height:1000px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42fe3d1d-e374-4dc4-a954-fd2143623faf")) {                    Plotly.newPlot(                        "42fe3d1d-e374-4dc4-a954-fd2143623faf",                        [{"hoverinfo":"text+y+x","marker":{"color":"blue","line":{"color":"DarkSlateGrey","width":1},"size":8},"mode":"markers","name":"Efficient Frontier","text":["Weights: BWE: 0.01, FRT: 0.01, GAS: 0.09, KDC: 0.10, KOS: 0.10, PPC: 0.01, PTB: 0.10, SAB: 0.09, SBT: 0.02, SSB: 0.10, VCB: 0.10, VIC: 0.03, VJC: 0.10, VNM: 0.03, VPI: 0.10","Weights: BWE: 0.02, FRT: 0.01, GAS: 0.08, KDC: 0.10, KOS: 0.10, PTB: 0.10, SAB: 0.09, SBT: 0.03, SSB: 0.10, VCB: 0.10, VIC: 0.04, VJC: 0.10, VNM: 0.02, VPI: 0.10","Weights: BWE: 0.03, EIB: 0.00, FRT: 0.01, GAS: 0.08, KDC: 0.10, KOS: 0.10, NAB: 0.01, PTB: 0.09, SAB: 0.08, SBT: 0.04, SSB: 0.10, VCB: 0.10, VIC: 0.04, VJC: 0.10, VNM: 0.02, VPI: 0.10","Weights: BWE: 0.03, EIB: 0.00, FRT: 0.01, GAS: 0.08, KDC: 0.10, KOS: 0.10, NAB: 0.01, PTB: 0.08, SAB: 0.07, SBT: 0.05, SSB: 0.10, VCB: 0.10, VIC: 0.05, VJC: 0.10, VNM: 0.01, VPI: 0.10","Weights: BWE: 0.03, EIB: 0.01, FRT: 0.01, GAS: 0.08, KDC: 0.10, KOS: 0.10, LPB: 0.00, NAB: 0.02, PTB: 0.08, SAB: 0.06, SBT: 0.06, SSB: 0.10, VCB: 0.10, VIC: 0.06, VJC: 0.09, VNM: 0.01, VPI: 0.10","Weights: BWE: 0.04, EIB: 0.01, FRT: 0.01, GAS: 0.07, KDC: 0.10, KOS: 0.10, LPB: 0.01, NAB: 0.02, PTB: 0.07, SAB: 0.06, SBT: 0.06, SSB: 0.10, VCB: 0.10, VIC: 0.07, VJC: 0.08, VNM: 0.00, VPI: 0.10","Weights: BWE: 0.04, EIB: 0.01, FRT: 0.00, GAS: 0.07, KDC: 0.10, KOS: 0.10, LPB: 0.01, NAB: 0.03, PTB: 0.06, SAB: 0.05, SBT: 0.07, SSB: 0.10, VCB: 0.10, VIC: 0.07, VJC: 0.07, VPI: 0.10","Weights: BWE: 0.05, EIB: 0.01, GAS: 0.07, KDC: 0.10, KOS: 0.10, LPB: 0.02, NAB: 0.03, PTB: 0.06, SAB: 0.04, SBT: 0.08, SJS: 0.00, SSB: 0.10, VCB: 0.10, VIC: 0.08, VJC: 0.06, VPI: 0.10, VTP: 0.00","Weights: BMP: 0.00, BWE: 0.05, EIB: 0.01, GAS: 0.07, KDC: 0.10, KOS: 0.10, LPB: 0.02, NAB: 0.04, PTB: 0.05, SAB: 0.04, SBT: 0.08, SJS: 0.01, SSB: 0.10, VCB: 0.10, VIC: 0.08, VJC: 0.05, VPI: 0.10, VTP: 0.00","Weights: BMP: 0.00, BWE: 0.05, EIB: 0.01, GAS: 0.06, KDC: 0.10, KOS: 0.10, LPB: 0.02, NAB: 0.04, PTB: 0.05, SAB: 0.03, SBT: 0.09, SJS: 0.01, SSB: 0.10, VCB: 0.10, VIC: 0.09, VJC: 0.04, VPI: 0.10, VTP: 0.01","Weights: BMP: 0.01, BWE: 0.05, EIB: 0.01, GAS: 0.06, KDC: 0.10, KOS: 0.10, LPB: 0.02, NAB: 0.05, PTB: 0.04, SAB: 0.03, SBT: 0.09, SJS: 0.01, SSB: 0.10, VCB: 0.10, VIC: 0.10, VJC: 0.03, VPI: 0.10, VTP: 0.01","Weights: BMP: 0.01, BWE: 0.05, EIB: 0.01, GAS: 0.05, KDC: 0.10, KOS: 0.10, LPB: 0.03, NAB: 0.05, PTB: 0.04, SAB: 0.02, SBT: 0.10, SJS: 0.02, SSB: 0.10, VCB: 0.10, VIC: 0.10, VJC: 0.02, VPI: 0.10, VTP: 0.01","Weights: BMP: 0.01, BWE: 0.06, EIB: 0.01, GAS: 0.05, KDC: 0.10, KOS: 0.10, LPB: 0.03, NAB: 0.06, PTB: 0.03, SAB: 0.01, SBT: 0.10, SJS: 0.02, SSB: 0.10, VCB: 0.10, VIC: 0.10, VJC: 0.00, VPI: 0.10, VTP: 0.02","Weights: BMP: 0.01, BWE: 0.06, EIB: 0.01, GAS: 0.04, KDC: 0.10, KOS: 0.10, LPB: 0.04, NAB: 0.06, PTB: 0.02, SAB: 0.01, SBT: 0.10, SJS: 0.03, SSB: 0.10, VCB: 0.10, VIC: 0.10, VPI: 0.10, VTP: 0.02","Weights: BMP: 0.02, BWE: 0.07, EIB: 0.01, GAS: 0.03, KDC: 0.10, KOS: 0.10, LPB: 0.04, NAB: 0.07, PTB: 0.02, SBT: 0.10, SJS: 0.03, SSB: 0.10, VCB: 0.10, VHM: 0.00, VIC: 0.10, VPI: 0.10, VTP: 0.02","Weights: BMP: 0.02, BWE: 0.07, EIB: 0.01, GAS: 0.01, KDC: 0.10, KOS: 0.10, LPB: 0.04, NAB: 0.07, PTB: 0.01, SBT: 0.10, SJS: 0.03, SSB: 0.10, VCB: 0.10, VHM: 0.01, VIC: 0.10, VPI: 0.10, VTP: 0.03","Weights: BMP: 0.02, BWE: 0.07, EIB: 0.01, KDC: 0.10, KOS: 0.10, LPB: 0.05, NAB: 0.08, SBT: 0.10, SJS: 0.04, SSB: 0.10, VCB: 0.09, VHM: 0.02, VIC: 0.10, VPI: 0 ...

# %%
plot_cov(cov_matrix)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b8df8b9d-64fd-4e16-8785-488582dc9ba4" class="plotly-graph-div" style="height:1400px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8df8b9d-64fd-4e16-8785-488582dc9ba4")) {                    Plotly.newPlot(                        "b8df8b9d-64fd-4e16-8785-488582dc9ba4",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z:.2f}","x":["AAA","ACB","ANV","BCG","BCM","BID","BMP","BSI","BVH","BWE","CII","CMG","CTD","CTG","CTR","CTS","DBC","DCM","DGC","DGW","DIG","DPM","DSE","DXG","DXS","EIB","EVF","FPT","FRT","FTS","GAS","GEX","GMD","GVR","HAG","HCM","HDB","HDC","HDG","HHV","HPG","HSG","HT1","KBC","KDC","KDH","KOS","LPB","MBB","MSB","MSN","MWG","NAB","NKG","NLG","NT2","OCB","PAN","PC1","PDR","PHR","PLX","PNJ","POW","PPC","PTB","PVD","PVT","REE","SAB","SBT","SCS","SHB","SIP","SJS","SSB","SSI","STB","SZC","TCB","TCH","TLG","TPB","VCB","VCG","VCI","VGC","VHC","VHM","VIB","VIC","VIX","VJC","VND","VNM","VPB","VPI","VRE","VTP"],"y":["AAA","ACB","ANV","BCG","BCM","BID","BMP","BSI","BVH","BWE","CII","CMG","CTD","CTG","CTR","CTS","DBC","DCM","DGC","DGW","DIG","DPM","DSE","DXG","DXS","EIB","EVF","FPT","FRT","FTS","GAS","GEX","GMD","GVR","HAG","HCM","HDB","HDC","HDG","HHV","HPG","HSG","HT1","KBC","KDC","KDH","KOS","LPB","MBB","MSB","MSN","MWG","NAB","NKG","NLG","NT2","OCB","PAN","PC1","PDR","PHR","PLX","PNJ","POW","PPC","PTB","PVD","PVT","REE","SAB","SBT","SCS","SHB","SIP","SJS","SSB","SSI","STB","SZC","TCB","TCH","TLG","TPB","VCB","VCG","VCI","VGC","VHC","VHM","VIB","VIC","VIX","VJC","VND","VNM","VPB","VPI","VRE","VTP"],"z":[[0.08859557764629239,0.03530800610844127,0.058519878745363074,0.05753508514458926,0.04855659097468098,0.034594901302606326,0.02810166787824862,0.05452767282643732,0.03919128425953298,0.020775330745655848,0.059934953768391364,0.06032239889280521,0.05767372311506281,0.04141336816960902,0.059140755873756584,0.06004089566222338,0.06169109650146355,0.06008987228524729,0.05455384018350648,0.05673153985728116,0.059564980435952444,0.05143282937244586,0.044811070817527644,0.06416971201102861,0.05976321193949351,0.042997480661049525,0.06453645158268471,0.03329711716961883,0.02942030845634149,0.06030960445730542,0.03452873806723454,0.05713973975225067,0.04708075978636877,0.06943155055364132,0.04971934646927861,0.0563057224058317,0.038715742672674205,0.06501899551042518,0.06594143726553231,0.04122976483864953,0.04883639773749695,0.05965777233588473,0.04518466175697895,0.059363218325253896,0.009465470644626679,0.047351730794925204,0.0018990341356406974,0.017616388998047648,0.0398634663290156,0.04193900946237612,0.04668541868528558,0.040237710203508026,0.025574187702137124,0.06237505384423585,0.05819104504225913,0.04308341592710574,0.035689509158920885,0.05546827346532485,0.05213491847641113,0.06658622409486287,0.055641843363610236,0.055049711224476015,0.04688613818062825,0.06006767431566542,0.036277090309964524,0.030505306909734214,0.05072249621876597,0.057796542591639466,0.03906941582023716,0.0271539768129546,0.030465733411464163,0.042248771687046806,0.03454350311626122,0.062143000418528625,0.04478700336369233,0.013082926160405397,0.05000203969585828,0.03974411183243039,0.06297449836081757,0.03691932148341507,0.07661101423413103,0.04862150975139941,0.04180697969848893,0.02863985576292481,0.04239982434013277,0.049419639847299454,0.05755507904694891,0.046162545861851034,0.023191294701083883,0.034075119516098755,0.019724805850217117,0.054584551268874376,0.03150505587419423,0.057389400122419054,0.02632561909365234,0.03566728005752325,0.02197055399814134,0.03068290131844474,0.05315691040948255],[0.03530800610844127,0.03946826763738756,0.040733800254632774,0.031441142452719624,0.03280260123624258,0.032654054779521775,0.028636950143481676,0.042597 ...

# %%
import plotly.graph_objects as go

def plot_price(data, ticker):
  fig = go.Figure()

  fig.add_trace(go.Scatter(
      x=data.index,          # datetime index
      y=data[ticker],       # close price
      mode='lines',
      name='Price',
      line=dict(color='blue')
  ))

  fig.update_layout(
      title=f'{ticker} Price Over Time',
      xaxis_title='Date',
      yaxis_title='Close Price',
      template='plotly_white',
      height=600,
      width=1400
  )

  fig.show()

plot_price(data, 'VIC')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ec5d0d68-c429-4225-a4fb-007275cdcad7" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec5d0d68-c429-4225-a4fb-007275cdcad7")) {                    Plotly.newPlot(                        "ec5d0d68-c429-4225-a4fb-007275cdcad7",                        [{"line":{"color":"blue"},"mode":"lines","name":"Price","x":["2015-12-31T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-18T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-25T00:00:00","2016-01-26T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00","2016-02-05T00:00:00","2016-02-15T00:00:00","2016-02-16T00:00:00","2016-02-17T00:00:00","2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-07T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-24T00:00:00","2016-03-25T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-14T00:00:00","2016-04-15T00:00:00","2016-04-19T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:00:00","2016-06-02T00:00:00","2016-06-03T00:00:00","2016-06-06T00:00:00","2016-06-07T00:00:00","2016-06-08T00:00:00","2016-06-09T00:00:00","2016-06-10T00:00:00","2016-06-13T00:00:00","2016-06-14T00:00:00","2016-06-15T00:00:00","2016-06-16T00:00:00","2016-06-17T00:00:00","2016-06-20T00:00:00","2016-06-21T00:00:00","2016-06-22T00:00:00","2016-06-23T00:00:00","2016-06-24T00:00:00","2016-06-27T00:00:00","2016-06-28T00:00:00","2016-06-29T00:00:00","2016-06-30T00:00:00","2016-07-01T00:00:00","2016-07-04T00:00:00","2016-07-05T00:00:00","2016-07-06T00:00:00","2016-07-07T00:00:00","2016-07-08T00:00:00","2016-07-11T00:00:00","2016-07-12T00:00:00","2016-07-13T00:00:00","2016-07-14T00:00:00","2016-07-15T00:00:00","2016-07-18T00:00:00","2016-07-19T00:00:00","2016-07-20T00:00:00","2016-07-21T00:00:00","2016-07-22T00:00:00","2016-07-25T00:00:00","2016-07-26T00:00:00","2016-07-27T00:00:00","2016-07-28T00:00:00","2016-07-29T00:00:00","2016-08-01T00:00:00","2016-08-02T00:00:00","2016-08-03T00:00:00","2016-08-04T00:00:00","2016-08-05T00:00:00","2016-08-08T00:00:00","2016-08-09T00:00:00","2016-08-10T00:00:00","2016-08-11T00:00:00","2016-08-12T00:00:00","2016-08 ...

# %%
plot_price(data, 'GMD')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e56d8148-2916-40a6-b7c6-5afa4a2ed267" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e56d8148-2916-40a6-b7c6-5afa4a2ed267")) {                    Plotly.newPlot(                        "e56d8148-2916-40a6-b7c6-5afa4a2ed267",                        [{"line":{"color":"blue"},"mode":"lines","name":"Price","x":["2015-12-31T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-18T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-25T00:00:00","2016-01-26T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00","2016-02-05T00:00:00","2016-02-15T00:00:00","2016-02-16T00:00:00","2016-02-17T00:00:00","2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-07T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-24T00:00:00","2016-03-25T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-14T00:00:00","2016-04-15T00:00:00","2016-04-19T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:00:00","2016-06-02T00:00:00","2016-06-03T00:00:00","2016-06-06T00:00:00","2016-06-07T00:00:00","2016-06-08T00:00:00","2016-06-09T00:00:00","2016-06-10T00:00:00","2016-06-13T00:00:00","2016-06-14T00:00:00","2016-06-15T00:00:00","2016-06-16T00:00:00","2016-06-17T00:00:00","2016-06-20T00:00:00","2016-06-21T00:00:00","2016-06-22T00:00:00","2016-06-23T00:00:00","2016-06-24T00:00:00","2016-06-27T00:00:00","2016-06-28T00:00:00","2016-06-29T00:00:00","2016-06-30T00:00:00","2016-07-01T00:00:00","2016-07-04T00:00:00","2016-07-05T00:00:00","2016-07-06T00:00:00","2016-07-07T00:00:00","2016-07-08T00:00:00","2016-07-11T00:00:00","2016-07-12T00:00:00","2016-07-13T00:00:00","2016-07-14T00:00:00","2016-07-15T00:00:00","2016-07-18T00:00:00","2016-07-19T00:00:00","2016-07-20T00:00:00","2016-07-21T00:00:00","2016-07-22T00:00:00","2016-07-25T00:00:00","2016-07-26T00:00:00","2016-07-27T00:00:00","2016-07-28T00:00:00","2016-07-29T00:00:00","2016-08-01T00:00:00","2016-08-02T00:00:00","2016-08-03T00:00:00","2016-08-04T00:00:00","2016-08-05T00:00:00","2016-08-08T00:00:00","2016-08-09T00:00:00","2016-08-10T00:00:00","2016-08-11T00:00:00","2016-08-12T00:00:00","2016-08 ...

# %%
plot_price(data, 'VNM')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c44c05f9-b16b-418e-baf4-e39c812ebd9d" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c44c05f9-b16b-418e-baf4-e39c812ebd9d")) {                    Plotly.newPlot(                        "c44c05f9-b16b-418e-baf4-e39c812ebd9d",                        [{"line":{"color":"blue"},"mode":"lines","name":"Price","x":["2015-12-31T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-18T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-25T00:00:00","2016-01-26T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00","2016-02-05T00:00:00","2016-02-15T00:00:00","2016-02-16T00:00:00","2016-02-17T00:00:00","2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-07T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-24T00:00:00","2016-03-25T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-14T00:00:00","2016-04-15T00:00:00","2016-04-19T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:00:00","2016-06-02T00:00:00","2016-06-03T00:00:00","2016-06-06T00:00:00","2016-06-07T00:00:00","2016-06-08T00:00:00","2016-06-09T00:00:00","2016-06-10T00:00:00","2016-06-13T00:00:00","2016-06-14T00:00:00","2016-06-15T00:00:00","2016-06-16T00:00:00","2016-06-17T00:00:00","2016-06-20T00:00:00","2016-06-21T00:00:00","2016-06-22T00:00:00","2016-06-23T00:00:00","2016-06-24T00:00:00","2016-06-27T00:00:00","2016-06-28T00:00:00","2016-06-29T00:00:00","2016-06-30T00:00:00","2016-07-01T00:00:00","2016-07-04T00:00:00","2016-07-05T00:00:00","2016-07-06T00:00:00","2016-07-07T00:00:00","2016-07-08T00:00:00","2016-07-11T00:00:00","2016-07-12T00:00:00","2016-07-13T00:00:00","2016-07-14T00:00:00","2016-07-15T00:00:00","2016-07-18T00:00:00","2016-07-19T00:00:00","2016-07-20T00:00:00","2016-07-21T00:00:00","2016-07-22T00:00:00","2016-07-25T00:00:00","2016-07-26T00:00:00","2016-07-27T00:00:00","2016-07-28T00:00:00","2016-07-29T00:00:00","2016-08-01T00:00:00","2016-08-02T00:00:00","2016-08-03T00:00:00","2016-08-04T00:00:00","2016-08-05T00:00:00","2016-08-08T00:00:00","2016-08-09T00:00:00","2016-08-10T00:00:00","2016-08-11T00:00:00","2016-08-12T00:00:00","2016-08 ...

# %%
plot_price(data, 'PNJ')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5c8eeab2-aa68-4dd9-9f7c-e142304ac7a5" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c8eeab2-aa68-4dd9-9f7c-e142304ac7a5")) {                    Plotly.newPlot(                        "5c8eeab2-aa68-4dd9-9f7c-e142304ac7a5",                        [{"line":{"color":"blue"},"mode":"lines","name":"Price","x":["2015-12-31T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-18T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-25T00:00:00","2016-01-26T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00","2016-02-05T00:00:00","2016-02-15T00:00:00","2016-02-16T00:00:00","2016-02-17T00:00:00","2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-07T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-24T00:00:00","2016-03-25T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-14T00:00:00","2016-04-15T00:00:00","2016-04-19T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:00:00","2016-06-02T00:00:00","2016-06-03T00:00:00","2016-06-06T00:00:00","2016-06-07T00:00:00","2016-06-08T00:00:00","2016-06-09T00:00:00","2016-06-10T00:00:00","2016-06-13T00:00:00","2016-06-14T00:00:00","2016-06-15T00:00:00","2016-06-16T00:00:00","2016-06-17T00:00:00","2016-06-20T00:00:00","2016-06-21T00:00:00","2016-06-22T00:00:00","2016-06-23T00:00:00","2016-06-24T00:00:00","2016-06-27T00:00:00","2016-06-28T00:00:00","2016-06-29T00:00:00","2016-06-30T00:00:00","2016-07-01T00:00:00","2016-07-04T00:00:00","2016-07-05T00:00:00","2016-07-06T00:00:00","2016-07-07T00:00:00","2016-07-08T00:00:00","2016-07-11T00:00:00","2016-07-12T00:00:00","2016-07-13T00:00:00","2016-07-14T00:00:00","2016-07-15T00:00:00","2016-07-18T00:00:00","2016-07-19T00:00:00","2016-07-20T00:00:00","2016-07-21T00:00:00","2016-07-22T00:00:00","2016-07-25T00:00:00","2016-07-26T00:00:00","2016-07-27T00:00:00","2016-07-28T00:00:00","2016-07-29T00:00:00","2016-08-01T00:00:00","2016-08-02T00:00:00","2016-08-03T00:00:00","2016-08-04T00:00:00","2016-08-05T00:00:00","2016-08-08T00:00:00","2016-08-09T00:00:00","2016-08-10T00:00:00","2016-08-11T00:00:00","2016-08-12T00:00:00","2016-08 ...

# %%
plot_price(data, 'VCB')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="39c4779b-61e0-4426-87d5-5837d332eb69" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39c4779b-61e0-4426-87d5-5837d332eb69")) {                    Plotly.newPlot(                        "39c4779b-61e0-4426-87d5-5837d332eb69",                        [{"line":{"color":"blue"},"mode":"lines","name":"Price","x":["2015-12-31T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-18T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-25T00:00:00","2016-01-26T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00","2016-02-05T00:00:00","2016-02-15T00:00:00","2016-02-16T00:00:00","2016-02-17T00:00:00","2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-07T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-24T00:00:00","2016-03-25T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-14T00:00:00","2016-04-15T00:00:00","2016-04-19T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:00:00","2016-06-02T00:00:00","2016-06-03T00:00:00","2016-06-06T00:00:00","2016-06-07T00:00:00","2016-06-08T00:00:00","2016-06-09T00:00:00","2016-06-10T00:00:00","2016-06-13T00:00:00","2016-06-14T00:00:00","2016-06-15T00:00:00","2016-06-16T00:00:00","2016-06-17T00:00:00","2016-06-20T00:00:00","2016-06-21T00:00:00","2016-06-22T00:00:00","2016-06-23T00:00:00","2016-06-24T00:00:00","2016-06-27T00:00:00","2016-06-28T00:00:00","2016-06-29T00:00:00","2016-06-30T00:00:00","2016-07-01T00:00:00","2016-07-04T00:00:00","2016-07-05T00:00:00","2016-07-06T00:00:00","2016-07-07T00:00:00","2016-07-08T00:00:00","2016-07-11T00:00:00","2016-07-12T00:00:00","2016-07-13T00:00:00","2016-07-14T00:00:00","2016-07-15T00:00:00","2016-07-18T00:00:00","2016-07-19T00:00:00","2016-07-20T00:00:00","2016-07-21T00:00:00","2016-07-22T00:00:00","2016-07-25T00:00:00","2016-07-26T00:00:00","2016-07-27T00:00:00","2016-07-28T00:00:00","2016-07-29T00:00:00","2016-08-01T00:00:00","2016-08-02T00:00:00","2016-08-03T00:00:00","2016-08-04T00:00:00","2016-08-05T00:00:00","2016-08-08T00:00:00","2016-08-09T00:00:00","2016-08-10T00:00:00","2016-08-11T00:00:00","2016-08-12T00:00:00","2016-08 ...

# %%
plot_price(data, 'ACB')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a57ac174-c5e1-4d59-ad39-b4e6c24165ff" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a57ac174-c5e1-4d59-ad39-b4e6c24165ff")) {                    Plotly.newPlot(                        "a57ac174-c5e1-4d59-ad39-b4e6c24165ff",                        [{"line":{"color":"blue"},"mode":"lines","name":"Price","x":["2015-12-31T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-18T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-25T00:00:00","2016-01-26T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00","2016-02-05T00:00:00","2016-02-15T00:00:00","2016-02-16T00:00:00","2016-02-17T00:00:00","2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-07T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-24T00:00:00","2016-03-25T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-14T00:00:00","2016-04-15T00:00:00","2016-04-19T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:00:00","2016-06-02T00:00:00","2016-06-03T00:00:00","2016-06-06T00:00:00","2016-06-07T00:00:00","2016-06-08T00:00:00","2016-06-09T00:00:00","2016-06-10T00:00:00","2016-06-13T00:00:00","2016-06-14T00:00:00","2016-06-15T00:00:00","2016-06-16T00:00:00","2016-06-17T00:00:00","2016-06-20T00:00:00","2016-06-21T00:00:00","2016-06-22T00:00:00","2016-06-23T00:00:00","2016-06-24T00:00:00","2016-06-27T00:00:00","2016-06-28T00:00:00","2016-06-29T00:00:00","2016-06-30T00:00:00","2016-07-01T00:00:00","2016-07-04T00:00:00","2016-07-05T00:00:00","2016-07-06T00:00:00","2016-07-07T00:00:00","2016-07-08T00:00:00","2016-07-11T00:00:00","2016-07-12T00:00:00","2016-07-13T00:00:00","2016-07-14T00:00:00","2016-07-15T00:00:00","2016-07-18T00:00:00","2016-07-19T00:00:00","2016-07-20T00:00:00","2016-07-21T00:00:00","2016-07-22T00:00:00","2016-07-25T00:00:00","2016-07-26T00:00:00","2016-07-27T00:00:00","2016-07-28T00:00:00","2016-07-29T00:00:00","2016-08-01T00:00:00","2016-08-02T00:00:00","2016-08-03T00:00:00","2016-08-04T00:00:00","2016-08-05T00:00:00","2016-08-08T00:00:00","2016-08-09T00:00:00","2016-08-10T00:00:00","2016-08-11T00:00:00","2016-08-12T00:00:00","2016-08 ...

# %%
plot_price(data, 'FPT')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dcad161b-d284-4636-9015-9deab5831e08" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dcad161b-d284-4636-9015-9deab5831e08")) {                    Plotly.newPlot(                        "dcad161b-d284-4636-9015-9deab5831e08",                        [{"line":{"color":"blue"},"mode":"lines","name":"Price","x":["2015-12-31T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-18T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-25T00:00:00","2016-01-26T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00","2016-02-05T00:00:00","2016-02-15T00:00:00","2016-02-16T00:00:00","2016-02-17T00:00:00","2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-07T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-24T00:00:00","2016-03-25T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-14T00:00:00","2016-04-15T00:00:00","2016-04-19T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:00:00","2016-06-02T00:00:00","2016-06-03T00:00:00","2016-06-06T00:00:00","2016-06-07T00:00:00","2016-06-08T00:00:00","2016-06-09T00:00:00","2016-06-10T00:00:00","2016-06-13T00:00:00","2016-06-14T00:00:00","2016-06-15T00:00:00","2016-06-16T00:00:00","2016-06-17T00:00:00","2016-06-20T00:00:00","2016-06-21T00:00:00","2016-06-22T00:00:00","2016-06-23T00:00:00","2016-06-24T00:00:00","2016-06-27T00:00:00","2016-06-28T00:00:00","2016-06-29T00:00:00","2016-06-30T00:00:00","2016-07-01T00:00:00","2016-07-04T00:00:00","2016-07-05T00:00:00","2016-07-06T00:00:00","2016-07-07T00:00:00","2016-07-08T00:00:00","2016-07-11T00:00:00","2016-07-12T00:00:00","2016-07-13T00:00:00","2016-07-14T00:00:00","2016-07-15T00:00:00","2016-07-18T00:00:00","2016-07-19T00:00:00","2016-07-20T00:00:00","2016-07-21T00:00:00","2016-07-22T00:00:00","2016-07-25T00:00:00","2016-07-26T00:00:00","2016-07-27T00:00:00","2016-07-28T00:00:00","2016-07-29T00:00:00","2016-08-01T00:00:00","2016-08-02T00:00:00","2016-08-03T00:00:00","2016-08-04T00:00:00","2016-08-05T00:00:00","2016-08-08T00:00:00","2016-08-09T00:00:00","2016-08-10T00:00:00","2016-08-11T00:00:00","2016-08-12T00:00:00","2016-08 ...

# %%
plot_price(data, 'GAS')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9e4da3a7-b0be-4ade-a89a-a88010724b37" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e4da3a7-b0be-4ade-a89a-a88010724b37")) {                    Plotly.newPlot(                        "9e4da3a7-b0be-4ade-a89a-a88010724b37",                        [{"line":{"color":"blue"},"mode":"lines","name":"Price","x":["2015-12-31T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-18T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-25T00:00:00","2016-01-26T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00","2016-02-05T00:00:00","2016-02-15T00:00:00","2016-02-16T00:00:00","2016-02-17T00:00:00","2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-07T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-24T00:00:00","2016-03-25T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-14T00:00:00","2016-04-15T00:00:00","2016-04-19T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:00:00","2016-06-02T00:00:00","2016-06-03T00:00:00","2016-06-06T00:00:00","2016-06-07T00:00:00","2016-06-08T00:00:00","2016-06-09T00:00:00","2016-06-10T00:00:00","2016-06-13T00:00:00","2016-06-14T00:00:00","2016-06-15T00:00:00","2016-06-16T00:00:00","2016-06-17T00:00:00","2016-06-20T00:00:00","2016-06-21T00:00:00","2016-06-22T00:00:00","2016-06-23T00:00:00","2016-06-24T00:00:00","2016-06-27T00:00:00","2016-06-28T00:00:00","2016-06-29T00:00:00","2016-06-30T00:00:00","2016-07-01T00:00:00","2016-07-04T00:00:00","2016-07-05T00:00:00","2016-07-06T00:00:00","2016-07-07T00:00:00","2016-07-08T00:00:00","2016-07-11T00:00:00","2016-07-12T00:00:00","2016-07-13T00:00:00","2016-07-14T00:00:00","2016-07-15T00:00:00","2016-07-18T00:00:00","2016-07-19T00:00:00","2016-07-20T00:00:00","2016-07-21T00:00:00","2016-07-22T00:00:00","2016-07-25T00:00:00","2016-07-26T00:00:00","2016-07-27T00:00:00","2016-07-28T00:00:00","2016-07-29T00:00:00","2016-08-01T00:00:00","2016-08-02T00:00:00","2016-08-03T00:00:00","2016-08-04T00:00:00","2016-08-05T00:00:00","2016-08-08T00:00:00","2016-08-09T00:00:00","2016-08-10T00:00:00","2016-08-11T00:00:00","2016-08-12T00:00:00","2016-08 ...

# %%
plot_price(data, 'HPG')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="72e3d314-b35c-4743-9e03-4ec4d09b8c54" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72e3d314-b35c-4743-9e03-4ec4d09b8c54")) {                    Plotly.newPlot(                        "72e3d314-b35c-4743-9e03-4ec4d09b8c54",                        [{"line":{"color":"blue"},"mode":"lines","name":"Price","x":["2015-12-31T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-18T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-25T00:00:00","2016-01-26T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00","2016-02-05T00:00:00","2016-02-15T00:00:00","2016-02-16T00:00:00","2016-02-17T00:00:00","2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-07T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-24T00:00:00","2016-03-25T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-14T00:00:00","2016-04-15T00:00:00","2016-04-19T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:00:00","2016-06-02T00:00:00","2016-06-03T00:00:00","2016-06-06T00:00:00","2016-06-07T00:00:00","2016-06-08T00:00:00","2016-06-09T00:00:00","2016-06-10T00:00:00","2016-06-13T00:00:00","2016-06-14T00:00:00","2016-06-15T00:00:00","2016-06-16T00:00:00","2016-06-17T00:00:00","2016-06-20T00:00:00","2016-06-21T00:00:00","2016-06-22T00:00:00","2016-06-23T00:00:00","2016-06-24T00:00:00","2016-06-27T00:00:00","2016-06-28T00:00:00","2016-06-29T00:00:00","2016-06-30T00:00:00","2016-07-01T00:00:00","2016-07-04T00:00:00","2016-07-05T00:00:00","2016-07-06T00:00:00","2016-07-07T00:00:00","2016-07-08T00:00:00","2016-07-11T00:00:00","2016-07-12T00:00:00","2016-07-13T00:00:00","2016-07-14T00:00:00","2016-07-15T00:00:00","2016-07-18T00:00:00","2016-07-19T00:00:00","2016-07-20T00:00:00","2016-07-21T00:00:00","2016-07-22T00:00:00","2016-07-25T00:00:00","2016-07-26T00:00:00","2016-07-27T00:00:00","2016-07-28T00:00:00","2016-07-29T00:00:00","2016-08-01T00:00:00","2016-08-02T00:00:00","2016-08-03T00:00:00","2016-08-04T00:00:00","2016-08-05T00:00:00","2016-08-08T00:00:00","2016-08-09T00:00:00","2016-08-10T00:00:00","2016-08-11T00:00:00","2016-08-12T00:00:00","2016-08 ...

# %%
plot_price(data, 'NLG')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1719d7bd-d9a6-49a0-89cf-9712fd01fe40" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1719d7bd-d9a6-49a0-89cf-9712fd01fe40")) {                    Plotly.newPlot(                        "1719d7bd-d9a6-49a0-89cf-9712fd01fe40",                        [{"line":{"color":"blue"},"mode":"lines","name":"Price","x":["2015-12-31T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-18T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-25T00:00:00","2016-01-26T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00","2016-02-05T00:00:00","2016-02-15T00:00:00","2016-02-16T00:00:00","2016-02-17T00:00:00","2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-07T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-24T00:00:00","2016-03-25T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-14T00:00:00","2016-04-15T00:00:00","2016-04-19T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:00:00","2016-06-02T00:00:00","2016-06-03T00:00:00","2016-06-06T00:00:00","2016-06-07T00:00:00","2016-06-08T00:00:00","2016-06-09T00:00:00","2016-06-10T00:00:00","2016-06-13T00:00:00","2016-06-14T00:00:00","2016-06-15T00:00:00","2016-06-16T00:00:00","2016-06-17T00:00:00","2016-06-20T00:00:00","2016-06-21T00:00:00","2016-06-22T00:00:00","2016-06-23T00:00:00","2016-06-24T00:00:00","2016-06-27T00:00:00","2016-06-28T00:00:00","2016-06-29T00:00:00","2016-06-30T00:00:00","2016-07-01T00:00:00","2016-07-04T00:00:00","2016-07-05T00:00:00","2016-07-06T00:00:00","2016-07-07T00:00:00","2016-07-08T00:00:00","2016-07-11T00:00:00","2016-07-12T00:00:00","2016-07-13T00:00:00","2016-07-14T00:00:00","2016-07-15T00:00:00","2016-07-18T00:00:00","2016-07-19T00:00:00","2016-07-20T00:00:00","2016-07-21T00:00:00","2016-07-22T00:00:00","2016-07-25T00:00:00","2016-07-26T00:00:00","2016-07-27T00:00:00","2016-07-28T00:00:00","2016-07-29T00:00:00","2016-08-01T00:00:00","2016-08-02T00:00:00","2016-08-03T00:00:00","2016-08-04T00:00:00","2016-08-05T00:00:00","2016-08-08T00:00:00","2016-08-09T00:00:00","2016-08-10T00:00:00","2016-08-11T00:00:00","2016-08-12T00:00:00","2016-08 ...

# %%
tickers = ['MBB', 'VCB', 'ACB', 'TCB', 'CTG', 'BID', 'TPB']

data = get_data(tickers, start, end)

# %%
returns = data.ffill().pct_change().dropna()

# # Step 2: Calculate expected returns and covariance matrix
expected_returns = returns.mean() * 252  # annualized
cov_matrix = returns.cov() * 252         # annualized

# %%
custom_bounds = {
    'VCB': (0, 0.7),
    'MBB': (0, 0.7),
    'ACB': (0, 0.7),
    'TCB': (0, 0.7),
    'CTG': (0, 0.7),
    'BID': (0, 0.7),
    'TCB': (0, 0.7)
}

target_returns = np.linspace(-0.05, 0.5, 30)
tickers = list(data.columns)
results = optimize_portfolio(tickers, expected_returns, cov_matrix, target_returns)

# %%
results
# Out:
#      Return  Volatility                                            Weights  \
# 0  0.139655    0.236743  [0.04510152605431818, 0.0, 2.6020852139652106e...
# 1  0.158621    0.231636  [0.2717709146038973, 0.0, 2.8189256484623115e-...
#
#    ACB_weight  BID_weight  CTG_weight  MBB_weight  TCB_weight  TPB_weight  \
# 0      0.0451         0.0         0.0      0.0000       0.302         0.1
# 1      0.2718         0.0         0.0      0.1363       0.000         0.1
#
#    VCB_weight
# 0      0.5529
# 1      0.4919

# %%
plot_portfolios(tickers, expected_returns, cov_matrix, results, custom_portfolio)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="14d66ce5-c241-4063-918e-d12d9a4ad5b2" class="plotly-graph-div" style="height:1000px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14d66ce5-c241-4063-918e-d12d9a4ad5b2")) {                    Plotly.newPlot(                        "14d66ce5-c241-4063-918e-d12d9a4ad5b2",                        [{"hoverinfo":"text+y+x","marker":{"color":"blue","line":{"color":"DarkSlateGrey","width":1},"size":8},"mode":"markers","name":"Efficient Frontier","text":["Weights: ACB: 0.05, TCB: 0.30, TPB: 0.10, VCB: 0.55","Weights: ACB: 0.27, MBB: 0.14, TPB: 0.10, VCB: 0.49"],"x":[0.2367432574710593,0.2316358524803725],"y":[0.13965517235476732,0.15862068966005663],"type":"scatter"},{"hoverinfo":"text+y+x","marker":{"color":"red","size":10,"symbol":"diamond"},"mode":"markers+text","name":"Single Stocks","text":["ACB","BID","CTG","MBB","TCB","TPB","VCB"],"textposition":"top center","x":[0.28957990078103574,0.34135917755921885,0.34125653250792964,0.30705653812850336,0.32864326659299803,0.32399400257909194,0.2602855837032694],"y":[0.170917840398846,0.1648509001514421,0.155693484493085,0.18032966043354043,0.11630626353159984,0.13103669303316673,0.15141759038420866],"type":"scatter"},{"hoverinfo":"text+y+x","hovertext":["ACB: 10%, FUEVFVND: 0%, GMD: 3%, HPG: 24%, MSN: 0%, NVL: 5%, PNJ: 16%, REE: 0%, VCB: 0%, VNM: 41%"],"marker":{"color":"green","size":12,"symbol":"star"},"mode":"markers+text","name":"Custom Portfolio","text":["Custom Portfolio"],"textposition":"bottom center","x":[0.028639452187244435],"y":[0.01690377441544587],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[ ...

# %% [markdown]
# ## 1 years ago

# %%
expected_returns = None
cov_matrix = None
results = None
returns = None
data = None

tickers = list(stock.listing.symbols_by_group('VN30'))


# Step 1: Download historical price data (using 'Close')
# Should be longer than a year, should be few years
# start = '2015-12-31'
# end = '2024-04-10'

data = get_data(tickers, start, end)
returns = data.pct_change().dropna()

# Step 2: Calculate expected returns and covariance matrix
expected_returns = returns.mean() * 252  # annualized
cov_matrix = returns.cov() * 252         # annualized
# Out:
# <ipython-input-102-1ad2b2de5ea6>:16: FutureWarning:
#
# The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.

# %%
# Step 3: Generate efficient frontier
target_returns = np.linspace(-0.05, 0.5, 30)

tickers = list(data.columns)

results = optimize_portfolio(tickers, expected_returns, cov_matrix, target_returns)

# %%
plot_portfolios(tickers, expected_returns, cov_matrix, results, custom_portfolio)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="520f9390-0220-4b96-a717-210235183d52" class="plotly-graph-div" style="height:1000px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("520f9390-0220-4b96-a717-210235183d52")) {                    Plotly.newPlot(                        "520f9390-0220-4b96-a717-210235183d52",                        [{"hoverinfo":"text+y+x","marker":{"color":"blue","line":{"color":"DarkSlateGrey","width":1},"size":8},"mode":"markers","name":"Efficient Frontier","text":["Weights: BCM: 0.06, BVH: 0.10, GAS: 0.06, PLX: 0.10, SAB: 0.10, SSB: 0.01, VCB: 0.10, VHM: 0.10, VIC: 0.10, VJC: 0.10, VNM: 0.10, VRE: 0.07","Weights: BCM: 0.06, BVH: 0.10, GAS: 0.05, PLX: 0.10, SAB: 0.10, SSB: 0.06, VCB: 0.13, VHM: 0.10, VIC: 0.10, VJC: 0.10, VNM: 0.10, VRE: 0.01","Weights: BCM: 0.06, BVH: 0.08, GAS: 0.04, PLX: 0.10, SAB: 0.10, SSB: 0.10, VCB: 0.15, VHM: 0.07, VIC: 0.10, VJC: 0.10, VNM: 0.10","Weights: ACB: 0.02, BCM: 0.07, BVH: 0.06, FPT: 0.02, GAS: 0.06, PLX: 0.08, SAB: 0.10, SSB: 0.10, VCB: 0.15, VHM: 0.03, VIB: 0.01, VIC: 0.10, VJC: 0.10, VNM: 0.10","Weights: ACB: 0.02, BCM: 0.07, BVH: 0.05, FPT: 0.06, GAS: 0.06, HDB: 0.01, PLX: 0.07, SAB: 0.10, SSB: 0.10, VCB: 0.15, VHM: 0.01, VIB: 0.01, VIC: 0.10, VJC: 0.10, VNM: 0.10","Weights: ACB: 0.03, BCM: 0.07, BVH: 0.03, FPT: 0.09, GAS: 0.06, HDB: 0.02, PLX: 0.05, SAB: 0.10, SSB: 0.10, VCB: 0.15, VIB: 0.00, VIC: 0.10, VJC: 0.10, VNM: 0.10","Weights: ACB: 0.05, BCM: 0.07, BVH: 0.00, FPT: 0.10, GAS: 0.07, HDB: 0.05, PLX: 0.01, SAB: 0.10, SSB: 0.10, VCB: 0.15, VIB: 0.00, VIC: 0.10, VJC: 0.10, VNM: 0.10","Weights: ACB: 0.07, BCM: 0.08, FPT: 0.10, GAS: 0.08, HDB: 0.07, SAB: 0.10, SSB: 0.10, VCB: 0.15, VIC: 0.05, VJC: 0.10, VNM: 0.10","Weights: ACB: 0.07, BCM: 0.08, BID: 0.01, FPT: 0.10, GAS: 0.08, HDB: 0.10, LPB: 0.00, SAB: 0.10, SSB: 0.10, VCB: 0.15, VIC: 0.01, VJC: 0.10, VNM: 0.10","Weights: ACB: 0.07, BCM: 0.08, BID: 0.03, FPT: 0.10, GAS: 0.07, HDB: 0.10, LPB: 0.03, SAB: 0.07, SSB: 0.10, VCB: 0.15, VJC: 0.10, VNM: 0.09","Weights: ACB: 0.08, BCM: 0.09, BID: 0.06, FPT: 0.10, GAS: 0.08, HDB: 0.10, LPB: 0.04, SAB: 0.04, SSB: 0.10, VCB: 0.15, VJC: 0.10, VNM: 0.06","Weights: ACB: 0.09, BCM: 0.09, BID: 0.08, FPT: 0.10, GAS: 0.09, HDB: 0.10, LPB: 0.06, SAB: 0.01, SSB: 0.10, VCB: 0.15, VJC: 0.10, VNM: 0.03","Weights: ACB: 0.08, BCM: 0.08, BID: 0.10, FPT: 0.10, GAS: 0.08, HDB: 0.10, LPB: 0.08, SSB: 0.10, SSI: 0.02, VCB: 0.15, VJC: 0.10","Weights: ACB: 0.09, BCM: 0.08, BID: 0.10, FPT: 0.10, GAS: 0.08, HDB: 0.10, LPB: 0.10, SSB: 0.10, SSI: 0.05, VCB: 0.15, VJC: 0.05","Weights: ACB: 0.10, BCM: 0.08, BID: 0.10, FPT: 0.10, GAS: 0.07, HDB: 0.10, LPB: 0.10, SSB: 0.10, SSI: 0.09, VCB: 0.15","Weights: ACB: 0.10, BCM: 0.01, BID: 0.10, FPT: 0.10, HDB: 0.10, LPB: 0.10, MBB: 0.10, SSB: 0.10, SSI: 0.10, STB: 0.04, VCB: 0.15"],"x":[0.17368520160807097,0.16337669824472656,0.1577498494308031,0.15536717925507376,0.15384276559571539,0.15306228710830222,0.15366319593334415,0.15609140403874489,0.16027838577036338,0.16645534964453726,0.17420925031728576,0.18309835531339622,0.19304737781769746,0.2048677133983607,0.2182600901066291,0.24053474049248358],"y":[-0.031034482758777453,-0.012068965517795915,0.006896551724304779,0.025862068965149965,0.04482758621040712,0.06379310344598214,0.0827586206890218,0.10172413793104136,0.12068965515896805,0.13965517242160183,0.15862068965536194,0.17758620689636723,0.19655172414336392,0.21551724139329279,0.23448275861941092,0.2534482758675694],"type":"scatter"},{"hoverinfo":"text+y+x","marker":{"color":"red","size":10,"symbol":"diamond"},"mode":"markers+text","name":"Single Stocks","text":["ACB","BCM","BID","BVH","CTG","FPT","GAS","GVR","HDB","HPG","LPB","MBB","MSN","MWG","PLX","SAB","SHB","SSB","SSI","STB","TCB","TPB","VCB","VHM","VIB","VIC","VJC","VNM","V ...

# %%
plot_cov(cov_matrix)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="235f1989-fbe4-4136-9232-d29f37c7460a" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("235f1989-fbe4-4136-9232-d29f37c7460a")) {                    Plotly.newPlot(                        "235f1989-fbe4-4136-9232-d29f37c7460a",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z:.2f}","x":["ACB","BCM","BID","BVH","CTG","FPT","GAS","GVR","HDB","HPG","LPB","MBB","MSN","MWG","PLX","SAB","SHB","SSB","SSI","STB","TCB","TPB","VCB","VHM","VIB","VIC","VJC","VNM","VPB","VRE"],"y":["ACB","BCM","BID","BVH","CTG","FPT","GAS","GVR","HDB","HPG","LPB","MBB","MSN","MWG","PLX","SAB","SHB","SSB","SSI","STB","TCB","TPB","VCB","VHM","VIB","VIC","VJC","VNM","VPB","VRE"],"z":[[0.0845202113839624,0.025576985673958587,0.05972645807042019,0.03829118395330292,0.06586302143912617,0.039628281666819434,0.025547024249969935,0.06480166775842656,0.054850136739489644,0.05345680481620736,0.07569654947991236,0.0686295475320733,0.036767847914547166,0.04955978525656252,0.03639417939667958,0.011699960744772331,0.0691627032920618,0.027633938852404845,0.07395274164005027,0.07530207275382059,0.06886844202114059,0.05831666839318472,0.033710451316686874,0.035249997960688756,0.060020425296565115,0.022070842177914735,0.011647515660386883,0.020615781548845878,0.05497511902494412,0.04216878973698907],[0.025576985673958587,0.12477998351568725,0.03155286019259965,0.034538568052646684,0.033135376332672536,0.02772698054717331,0.03957329070750245,0.06208165994363776,0.025436690350526737,0.034706555818410874,0.035652466420108955,0.03176781835027135,0.038987220421398065,0.043360498272366675,0.02814302724237813,0.014189190408036857,0.0351335695793362,0.016294487110742047,0.04966365260154072,0.04281005231105456,0.03553322973339367,0.03144139662869396,0.017060371139683034,0.03737677280236974,0.03004251100904605,0.024669760940834746,0.011881843343745589,0.012690548607049604,0.0318777498314343,0.044492513190693285],[0.05972645807042019,0.03155286019259965,0.11720195871410898,0.046455685625838516,0.08254799265248157,0.039708160186148964,0.03462187081684036,0.07041139743767878,0.058541387050135826,0.05889231992471713,0.08032041772352962,0.0742703384648975,0.042433607790728994,0.05431276492429334,0.0447768500876539,0.020067932515076544,0.07108959970493121,0.02879401543617738,0.08270396622653628,0.08666233257423027,0.07006520663592149,0.060956599664337134,0.03795605287509894,0.03798112302445393,0.061131740558684686,0.02601304220934353,0.013032422088032855,0.026167503441317824,0.05772633436204927,0.05891740574214869],[0.03829118395330292,0.034538568052646684,0.046455685625838516,0.09387949241606619,0.04744399723825081,0.03577411428666642,0.036168451087873685,0.07751423405234785,0.032709757012333536,0.04538254794876044,0.05296735767493201,0.048436788161235554,0.0429269986083021,0.05175905784908551,0.04566874543059062,0.01923719402639506,0.055032385696748155,0.022695778219288806,0.06564691950716885,0.05150584085720804,0.046484084384593616,0.03979187608094381,0.019787493520142016,0.03585217807665396,0.04181300439464159,0.023168897733753642,0.014178877791744728,0.025945983747143103,0.04316422177025324,0.04470424430093843],[0.06586302143912617,0.033135376332672536,0.08254799265248157,0.04744399723825081,0.11884166303354259,0.04522037082710032,0.035471285740880036,0.07438944454942521,0.06604908850765745,0.06753095767357988,0.09218858749723093,0.085769534260161,0.04976505003327989,0.05745543998356915,0.043446682835521805,0.018873947146993187,0.07722662304831551,0.03346952811454043,0.09662584639161914,0.09388809665690209,0.0798518800637036,0.07214093916164332,0.04069827424563017,0.04397442647033608,0.07045039051100785,0.030243190108081006,0.010130721918848897,0 ...

# %%
data['VIC']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-38a61639b621> in <cell line: 0>()
# ----> 1 data['VIC']
#
# NameError: name 'data' is not defined
